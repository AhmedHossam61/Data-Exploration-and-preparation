# %% [markdown]
# # Introduction
# ### ML lifeCycle
#
# 1- define prject objectives
#
# 2- Data Acquisition =>  دا تجميل الداتا يعني بمختلف الطرق و تعتبر اكبرر الخطوات اللي بتاخد وقت لو مش متاحة
#
# 3- Data Exploration => دا اني ابدا اتفرج عالداتا بتاعتي و اشوف اي عيوبها من اوت لايرز او قيم مفقودة او غيره
#
# 4- Data preparation => هنا الاكشن اللي باخده بعد ما اكتشف اللي فالداتا بتاعتي
#
# 5- ML Model         =>
#
# 6- Train
#
# 7- Evaluate
#
# من المرحلة ال 3 و 4 اقدر اعرف هل الداتا بتاعتي دي خطية ولا لأ بحيث اعرف ممكن استعمل linear model or not

# %% [markdown]
# # Dataset File Format - CSV
#
# ![image.png](attachment:image.png)
#
# JSON , CSV are very important and widely used
#
# CSV => Comma seperated Values => ميعتبرش ملف اكسيل
#
# JSON=> JavaScript Object Notation
